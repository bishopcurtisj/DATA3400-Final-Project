# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('C:\\Users\\bisho\\OneDrive\\Documents\\DATA3400\\Final Project\\nbaplayersdraft.csv')

# %%
data['NBA Champion']=''

# %%
NBA_Champs=['DET','DET','CHI','CHI','CHI','HOU','HOU','CHI','CHI','CHI','SAS', 'LAL','LAL','LAL','SAS','DET','SAS','MIA','SAS','BOS','LAL','LAL', 'DAL','MIA','MIA','SAS','GSW','CLE','GSW','GSW','TOR','LAL','MIL']
len(NBA_Champs)
display(NBA_Champs[32])
# Out:
# 'MIL'

# %%
for year in range(1989,2022):
    i= year-1989
    data.loc[data.year==year, 'NBA Champion']=NBA_Champs[i]

# %%
display(data)
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0    id  year  rank  overall_pick  \
# 0                0             0           0     1  1989     1             1
# 1                1             1           1     2  1989     2             2
# 2                2             2           2     3  1989     3             3
# 3                3             3           3     4  1989     4             4
# 4                4             4           4     5  1989     5             5
# ...            ...           ...         ...   ...   ...   ...           ...
# 1917          1917          1917        1917  1918  2021    56            56
# 1918          1918          1918        1918  1919  2021    57            57
# 1919          1919          1919        1919  1920  2021    58            58
# 1920          1920          1920        1920  1921  2021    59            59
# 1921          1921          1921        1921  1922  2021    60            60
#
# ...

# %%
#data.to_csv('C:\\Users\\bisho\\OneDrive\\Documents\\DATA3400\\Datasets\\nbaplayersdraft.csv')

# %%
record=pd.read_csv('C:\\Users\\bisho\\OneDrive\\Documents\\DATA3400\\Datasets\\NBA_Records.csv')
df=pd.DataFrame()
team=list(record.columns)
season=range(1989,2022)
df['Season'] = pd.DataFrame(np.repeat(season, 30, axis=0))
display(df)
team=team[3:]
# Out:
#      Season
# 0      1989
# 1      1989
# 2      1989
# 3      1989
# 4      1989
# ..      ...
# 985    2021
# 986    2021
# 987    2021
# 988    2021
# 989    2021
#
# [990 rows x 1 columns]

# %%
len(team)
# Out:
# 30

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
row=record.loc[0, :].values.flatten().tolist()
display(row[3:])
# Out:
# [43,
#  51,
#  44,
#  46,
#  43.0,
#  44,
#  52,
#  48,
#  23,
#  53,
#  20,
#  25,
#  42,
#  33,
#  56.0,
#  53,
#  51,
#  46,
#  36.0,
#  37,
#  24,
#  22,
#  51,
#  64,
#  27,
#  30,
#  34,
#  48.0,
#  49,
#  35]

# %%
teams=list()
for i in range(33):
    teams=teams+team
display(teams)
# Out:
# ['ATL',
#  'BOS',
#  'BRK',
#  'CHI',
#  'CHO',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GSW',
#  'HOU',
#  'IND',
#  'LAC',
#  'LAL',
#  'MEM',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NOP',
#  'NYK',
#  'OKC',
#  'ORL',
#  'PHI',
#  'PHO',
#  'POR',
#  'SAC',
#  'SAS',
#  'TOR',
#  'UTA',
#  'WAS',
#  'ATL',
#  'BOS',
#  'BRK',
#  'CHI',
#  'CHO',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GSW',
#  'HOU',
#  'IND',
#  'LAC',
#  'LAL',
#  'MEM',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NOP',
#  'NYK',
#  'OKC',
#  'ORL',
#  'PHI',
#  'PHO',
#  'POR',
#  'SAC',
#  'SAS',
#  'TOR',
#  'UTA',
#  'WAS',
#  'ATL',
#  'BOS',
#  'BRK',
#  'CHI',
#  'CHO',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GSW',
#  'HOU',
#  'IND',
#  'LAC',
#  'LAL',
#  'MEM',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NOP',
#  'NYK',
#  'OKC',
#  'ORL',
#  'PHI',
#  'PHO',
#  'POR',
#  'SAC',
#  'SAS',
#  'TOR',
#  'UTA',
#  'WAS',
#  'ATL',
#  'BOS',
#  'BRK',
#  'CHI',
#  'CHO',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GSW',
# ...

# %%
len(row)
# Out:
# 33

# %%
df['Teams']=teams
display(df)
# Out:
#      Season Teams
# 0      1989   ATL
# 1      1989   BOS
# 2      1989   BRK
# 3      1989   CHI
# 4      1989   CHO
# ..      ...   ...
# 985    2021   SAC
# 986    2021   SAS
# 987    2021   TOR
# 988    2021   UTA
# 989    2021   WAS
#
# [990 rows x 2 columns]

# %%
records=list()
for i in range(33):
    row_list = record.loc[i, :].values.flatten().tolist()
    row_list=row_list[3:]
    records=row_list+records
display(records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15988\3941567341.py in <module>
#       1 records=list()
#       2 for i in range(33):
# ----> 3     row_list = record.loc[i, :].values.flatten().tolist()
#       4     row_list=row_list[3:]
#       5     records=row_list+records
#
# NameError: name 'record' is not defined

# %%
# Out:
# [31,
#  55,
#  nan,
#  56,
#  23,
#  59,
#  54,
#  53,
#  18,
#  41,
#  45,
#  nan,
#  22,
#  44,
#  18,
#  nan,
#  63,
#  30,
#  42,
#  41,
#  37,
#  59,
#  43,
#  47,
#  42,
#  19.0,
#  55,
#  17,
#  52,
#  41,
#  30,
#  54,
#  nan,
#  55,
#  25,
#  63,
#  55,
#  44,
#  31,
#  41,
#  39,
#  nan,
#  29,
#  48,
#  24,
#  nan,
#  58,
#  31,
#  41,
#  52,
#  44,
#  50,
#  20,
#  28,
#  33,
#  26.0,
#  61,
#  26,
#  56,
#  43,
#  25,
#  55,
#  nan,
#  47,
#  29,
#  57,
#  53,
#  35,
#  21,
#  47,
#  51,
#  nan,
#  15,
#  31,
#  38,
#  nan,
#  43,
#  45,
#  40,
#  42,
#  55,
#  48,
#  24,
#  22,
#  57,
#  31.0,
#  67,
#  40,
#  51,
#  38,
#  22,
#  47,
#  nan,
#  49,
#  25,
#  51,
#  62,
#  26,
#  41,
#  55,
#  60,
#  nan,
#  19,
#  28,
#  36,
#  nan,
#  39,
#  41,
#  41,
#  55,
#  34,
#  40,
#  36,
#  11,
#  54,
#  44.0,
#  57,
#  43,
#  48,
#  43,
#  24,
#  53,
#  nan,
#  55,
#  28,
#  47,
#  56,
#  25,
#  50,
#  63,
#  57,
#  nan,
#  20,
#  20,
#  42,
#  nan,
#  33,
#  27,
#  47,
# ...

# %%
df['Wins']=records
display(df)
# Out:
#      Season Teams  Wins
# 0      1989   ATL  41.0
# 1      1989   BOS  52.0
# 2      1989   BRK  17.0
# 3      1989   CHI  55.0
# 4      1989   CHO  19.0
# ..      ...   ...   ...
# 985    2021   SAC  30.0
# 986    2021   SAS  34.0
# 987    2021   TOR  48.0
# 988    2021   UTA  49.0
# 989    2021   WAS  35.0
#
# [990 rows x 3 columns]

# %%
#df.to_csv('C:\\Users\\bisho\\OneDrive\\Documents\\DATA3400\\Datasets\\TeamWins.csv')

# %%
ap=[]
for year in (1995,2022):
    for i in range(5):
        pick=data.loc(data.year==year-i,data.overall_pick)
        display(type(pick))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15988\1653827526.py in <module>
#       2 for year in (1995,2022):
#       3     for i in range(5):
# ----> 4         pick=data.loc(data.year==year-i,data.overall_pick)
#       5         display(type(pick))
#
# TypeError: __call__() takes from 1 to 2 positional arguments but 3 were given

# %%
#Average pick for a team over five years starting 3 years prior 
data['AveragePick3']
#Average pick for a team over last five years
data['AveragePick']
